# %%
import pandas as pd

# %%
taxi_jan_2024 = pd.read_csv('yellow_tripdata_2024-01.csv', nrows = 100)
taxi_jan_2024.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1         1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2         1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3         1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4         1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.72         1.0                  N           186            79
# 1           1.80         1.0                  N           140           236
# 2           4.70         1.0                  N           236            79
# 3           1.40         1.0                  N            79           211
# 4           0.80         1.0                  N           211           148
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2         17.7    1.0      0.5        0.00           0.0
# 1             1         10.0    3.5      0.5        3.75           0.0
# 2             1         23.3    3.5      0.5        3.00           0.0
# 3             1         10.0    3.5      0.5        2.00           0.0
# 4             1          7.9    3.5      0.5        3.20           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee
# 0                    1.0         22.70                   2.5          0.0
# 1                    1.0         18.75                   2.5          0.0
# 2                    1.0         31.30                   2.5          0.0
# 3                    1.0         17.00                   2.5          0.0
# 4                    1.0         16.10                   2.5          0.0

# %%
taxi_jan_2024.tpep_pickup_datetime = pd.to_datetime(taxi_jan_2024.tpep_pickup_datetime)
taxi_jan_2024.tpep_dropoff_datetime = pd.to_datetime(taxi_jan_2024.tpep_dropoff_datetime)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
print(pd.io.sql.get_schema(taxi_jan_2024, name='yellow_taxi_data', con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	"Airport_fee" FLOAT(53)
# )

# %%
df_iter = pd.read_csv('yellow_tripdata_2024-01.csv', iterator=True, chunksize=100000)
df_iter

# %%
taxi_jan_2024 = next(df_iter)
taxi_jan_2024
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 300000         1  2024-01-04 19:28:45   2024-01-04 19:54:51              1.0
# 300001         2  2024-01-04 19:41:16   2024-01-04 19:43:31              1.0
# 300002         2  2024-01-04 19:41:16   2024-01-04 19:43:31              1.0
# 300003         2  2024-01-04 19:08:54   2024-01-04 19:25:44              1.0
# 300004         2  2024-01-04 19:30:29   2024-01-04 19:43:47              1.0
# ...          ...                  ...                   ...              ...
# 399995         1  2024-01-05 19:26:04   2024-01-05 19:41:51              1.0
# 399996         1  2024-01-05 19:43:09   2024-01-05 19:52:58              1.0
# 399997         2  2024-01-05 19:41:30   2024-01-05 19:54:22              1.0
# 399998         1  2024-01-05 19:16:53   2024-01-05 19:23:33              1.0
# 399999         1  2024-01-05 19:43:11   2024-01-05 19:48:51              1.0
#
#         trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 300000           0.00         1.0                  N            83
# 300001           0.24         1.0                  N           239
# 300002           0.24         1.0                  N           239
# 300003           2.29         1.0                  N           238
# 300004           2.26         1.0                  N           163
# ...               ...         ...                ...           ...
# 399995           1.80         1.0                  N           237
# 399996           1.40         1.0                  N           230
# 399997           2.18         1.0                  N           166
# 399998           1.00         1.0                  N           107
# 399999           1.00         1.0                  N           237
#
#         DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 300000            51             1        52.44    0.0      0.5        0.00
# 300001           239             3        -4.40   -2.5     -0.5        0.00
# 300002           239             3         4.40    2.5      0.5        0.00
# 300003           163             1        16.30    2.5      0.5        4.56
# 300004           113             1        14.90    2.5      0.5        1.50
# ...              ...           ...          ...    ...      ...         ...
# 399995           230             1        14.20    5.0      0.5        4.15
# 399996           239             1        10.00    5.0      0.5        3.30
# 399997           236             1        14.20    2.5      0.5        4.14
# 399998           137             1         8.60    5.0      0.5        3.00
# 399999           141             1         8.60    5.0      0.5        3.00
#
#         tolls_amount  improvement_surcharge  total_amount  \
# 300000         13.88                    1.0         67.82
# 300001          0.00                   -1.0        -10.90
# 300002          0.00                    1.0         10.90
# 300003          0.00                    1.0         27.36
# 300004          0.00                    1.0         22.90
# ...              ...                    ...           ...
# 399995          0.00                    1.0         24.85
# 399996          0.00                    1.0         19.80
# 399997          0.00                    1.0         24.84
# 399998          0.00                    1.0         18.10
# 399999          0.00                    1.0         18.10
#
#         congestion_surcharge  Airport_fee
# 300000                   0.0          0.0
# 300001                  -2.5          0.0
# 300002                   2.5          0.0
# 300003                   2.5          0.0
# 300004                   2.5          0.0
# ...                      ...          ...
# 399995                   2.5          0.0
# 399996                   2.5          0.0
# 399997                   2.5          0.0
# 399998                   2.5          0.0
# 399999                   2.5          0.0
#
# [100000 rows x 19 columns]

# %%
taxi_jan_2024.tpep_pickup_datetime = pd.to_datetime(taxi_jan_2024.tpep_pickup_datetime)
taxi_jan_2024.tpep_dropoff_datetime = pd.to_datetime(taxi_jan_2024.tpep_dropoff_datetime)

# %%
taxi_jan_2024.head(n=0).to_sql(name ='yellow_taxi_data',con=engine, if_exists='replace')
# Out:
# 0

# %%
# %time taxi_jan_2024.to_sql(name ='yellow_taxi_data',con=engine, if_exists='append')
# Out:
# CPU times: user 3.21 s, sys: 145 ms, total: 3.35 s
# Wall time: 5.88 s
# 1000

# %%
from time import time

# %%
while True:
    
    t_start = time()
    
    taxi_jan_2024 = next(df_iter)
    
    taxi_jan_2024.tpep_pickup_datetime = pd.to_datetime(taxi_jan_2024.tpep_pickup_datetime)
    taxi_jan_2024.tpep_dropoff_datetime = pd.to_datetime(taxi_jan_2024.tpep_dropoff_datetime)
    
    taxi_jan_2024.to_sql(name ='yellow_taxi_data',con=engine, if_exists='append')
    
    t_end = time()
    
    print('inserted another chunk, took %.3f seconds' % (t_end - t_start))
# Out:
# inserted another chunk, took 5.717 seconds
# inserted another chunk, took 5.758 seconds
# inserted another chunk, took 5.575 seconds
# inserted another chunk, took 5.657 seconds
# inserted another chunk, took 5.611 seconds
# inserted another chunk, took 5.966 seconds
# inserted another chunk, took 5.824 seconds
# inserted another chunk, took 5.836 seconds
# inserted another chunk, took 5.744 seconds
# inserted another chunk, took 5.982 seconds
# inserted another chunk, took 6.063 seconds
# inserted another chunk, took 5.959 seconds
# inserted another chunk, took 5.854 seconds
# inserted another chunk, took 5.899 seconds
# inserted another chunk, took 5.872 seconds
# inserted another chunk, took 5.873 seconds
# inserted another chunk, took 5.953 seconds
# inserted another chunk, took 5.899 seconds
# inserted another chunk, took 6.256 seconds
# inserted another chunk, took 5.970 seconds
# inserted another chunk, took 6.263 seconds
# inserted another chunk, took 6.268 seconds
# inserted another chunk, took 6.210 seconds
# inserted another chunk, took 5.947 seconds
# /var/folders/fy/xyh07_qn3vd2x6f9bgwmgxsm0000gn/T/ipykernel_59556/3031054024.py:5: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   taxi_jan_2024 = next(df_iter)
# inserted another chunk, took 5.434 seconds
# inserted another chunk, took 3.500 seconds
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[20], line 5
#       1 while True:
#       3     t_start = time()
# ----> 5     taxi_jan_2024 = next(df_iter)
#       7     taxi_jan_2024.tpep_pickup_datetime = pd.to_datetime(taxi_jan_2024.tpep_pickup_datetime)
#       8     taxi_jan_2024.tpep_dropoff_datetime = pd.to_datetime(taxi_jan_2024.tpep_dropoff_datetime)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py:1843, in TextFileReader.__next__(self)
#    1841 def __next__(self) -> DataFrame:
#    1842     try:
# -> 1843         return self.get_chunk()
#    1844     except StopIteration:
#    1845         self.close()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py:1985, in TextFileReader.get_chunk(self, size)
#    1983         raise StopIteration
#    1984     size = min(size, self.nrows - self._currow)
# -> 1985 return self.read(nrows=size)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:863, in pandas._libs.parsers.TextReader.read_low_memory()
#
# StopIteration:
